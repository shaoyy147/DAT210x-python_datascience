# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module4- Lab2

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

from sklearn import preprocessing

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# ### Some Boilerplate Code

# %% [markdown]
# For your convenience, we've included some boilerplate code here which will help you out. You aren't expected to know how to write this code on your own at this point, but it'll assist with your visualizations. We've added some notes to the code in case you're interested in knowing what it's doing:

# %% [markdown]
# ### A Note on SKLearn's `.transform()` calls:

# %% [markdown]
# Any time you perform a transformation on your data, you lose the column header names because the output of SciKit-Learn's `.transform()` method is an NDArray and not a daraframe.
#
# This actually makes a lot of sense because there are essentially two types of transformations:
# - Those that adjust the scale of your features, and
# - Those that change alter the number of features, perhaps even changing their values entirely.
#
# An example of adjusting the scale of a feature would be changing centimeters to inches. Changing the feature entirely would be like using PCA to reduce 300 columns to 30. In either case, the original column's units have either been altered or no longer exist at all, so it's up to you to assign names to your columns after any transformation, if you'd like to store the resulting NDArray back into a dataframe.

# %%
def scaleFeaturesDF(df):
    # Feature scaling is a type of transformation that only changes the
    # scale, but not number of features. Because of this, we can still
    # use the original dataset's column names... so long as we keep in
    # mind that the _units_ have been altered:

    scaled = preprocessing.StandardScaler().fit_transform(df)
    scaled = pd.DataFrame(scaled, columns=df.columns)
    
    print("New Variances:\n", scaled.var())
    print("New Describe:\n", scaled.describe())
    return scaled

# %% [markdown]
# SKLearn contains many methods for transforming your features by scaling them, a type of pre-processing):
#     - `RobustScaler`
#     - `Normalizer`
#     - `MinMaxScaler`
#     - `MaxAbsScaler`
#     - `StandardScaler`
#     - ...
#
# http://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing
#
# However in order to be effective at PCA, there are a few requirements that must be met, and which will drive the selection of your scaler. PCA requires your data is standardized -- in other words, it's _mean_ should equal 0, and it should have unit variance.
#
# SKLearn's regular `Normalizer()` doesn't zero out the mean of your data, it only clamps it, so it could be inappropriate to use depending on your data. `MinMaxScaler` and `MaxAbsScaler` both fail to set a unit variance, so you won't be using them here either. `RobustScaler` can work, again depending on your data (watch for outliers!). So for this assignment, you're going to use the `StandardScaler`. Get familiar with it by visiting these two websites:
#
# - http://scikit-learn.org/stable/modules/preprocessing.html#preprocessing-scaler
# - http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler

# %% [markdown]
# Lastly, some code to help with visualizations:

# %%
def drawVectors(transformed_features, components_, columns, plt, scaled):
    if not scaled:
        return plt.axes() # No cheating ;-)

    num_columns = len(columns)

    # This funtion will project your *original* feature (columns)
    # onto your principal component feature-space, so that you can
    # visualize how "important" each one was in the
    # multi-dimensional scaling

    # Scale the principal components by the max value in
    # the transformed set belonging to that component
    xvector = components_[0] * max(transformed_features[:,0])
    yvector = components_[1] * max(transformed_features[:,1])

    ## visualize projections

    # Sort each column by it's length. These are your *original*
    # columns, not the principal components.
    important_features = { columns[i] : math.sqrt(xvector[i]**2 + yvector[i]**2) for i in range(num_columns) }
    important_features = sorted(zip(important_features.values(), important_features.keys()), reverse=True)
    print("Features by importance:\n", important_features)

    ax = plt.axes()

    for i in range(num_columns):
        # Use an arrow to project each original feature as a
        # labeled vector on your principal component axes
        plt.arrow(0, 0, xvector[i], yvector[i], color='b', width=0.0005, head_width=0.02, alpha=0.75)
        plt.text(xvector[i]*1.2, yvector[i]*1.2, list(columns)[i], color='b', alpha=0.75)

    return ax

# %% [markdown]
# ### And Now, The Assignment

# %%
# Do * NOT * alter this line, until instructed!
scaleFeatures = True

# %% [markdown]
# Load up the dataset specified on the lab instructions page and remove any and all _rows_ that have a NaN in them. You should be a pro at this by now ;-)
#
# **QUESTION**: Should the `id` column be included in your dataset as a feature?

# %%
# .. your code here ..
df = pd.read_csv('E:\Python_SYY\edx\DAT210x\Module4\Datasets\kidney_disease.csv')
df.dropna(axis =0, inplace = True)
df2 = df.drop(['id', 'classification'],axis = 1)
df2.reset_index(inplace = True, drop = True)
df2
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 1    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 2    63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 3    68.0   80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 4    61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 5    48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 6    69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 7    73.0   70.0  1.005  0.0  0.0    normal    normal  notpresent  notpresent
# 8    73.0   80.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 9    46.0   60.0  1.010  1.0  0.0    normal    normal  notpresent  notpresent
# 10   56.0   90.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 11   48.0   80.0  1.005  4.0  0.0  abnormal  abnormal  notpresent     present
# 12   59.0   70.0  1.010  3.0  0.0    normal  abnormal  notpresent  notpresent
# 13   63.0  100.0  1.010  2.0  2.0    normal    normal  notpresent     present
# 14   56.0   70.0  1.015  4.0  1.0  abnormal    normal  notpresent  notpresent
# 15   71.0   70.0  1.010  3.0  0.0    normal  abnormal     present     present
# 16   73.0  100.0  1.010  3.0  2.0  abnormal  abnormal     present  notpresent
# 17   71.0   60.0  1.015  4.0  0.0    normal    normal  notpresent  notpresent
# 18   52.0   90.0  1.015  4.0  3.0    normal  abnormal  notpresent  notpresent
# 19   50.0   90.0  1.010  2.0  0.0    normal  abnormal     present     present
# 20   70.0  100.0  1.015  4.0  0.0    normal    normal  notpresent  notpresent
# 21   60.0   90.0  1.010  2.0  0.0  abnormal    normal  notpresent  notpresent
# 22   60.0   60.0  1.010  3.0  1.0    normal  abnormal     present  notpresent
# 23   55.0   90.0  1.010  2.0  1.0  abnormal  abnormal  notpresent  notpresent
# 24   62.0   70.0  1.025  3.0  0.0    normal  abnormal  notpresent  notpresent
# 25   59.0   80.0  1.010  1.0  0.0  abnormal    normal  notpresent  notpresent
# 26   83.0   70.0  1.020  3.0  0.0    normal    normal  notpresent  notpresent
# 27   21.0   90.0  1.010  4.0  0.0    normal  abnormal     present     present
# 28   45.0   70.0  1.025  2.0  0.0    normal  abnormal     present  notpresent
# 29   64.0   60.0  1.010  4.0  1.0  abnormal  abnormal  notpresent     present
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 128  30.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 129  75.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 130  69.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 131  28.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 132  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 133  61.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 134  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 135  70.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 136  58.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 137  64.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 138  62.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 139  59.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 140  48.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 141  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 142  57.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 143  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 144  46.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 145  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 146  51.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 147  41.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 148  52.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 149  36.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 150  57.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 151  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 152  50.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 153  55.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 154  42.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 155  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 156  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 157  58.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
#        bgr ...   hemo  pcv      wc   rc  htn   dm  cad appet   pe  ane
# 0    117.0 ...   11.2   32    6700  3.9  yes   no   no  poor  yes  yes
# 1     70.0 ...    9.5   29   12100  3.7  yes  yes   no  poor   no  yes
# 2    380.0 ...   10.8   32    4500  3.8  yes  yes   no  poor  yes   no
# 3    157.0 ...    5.6   16   11000  2.6  yes  yes  yes  poor  yes   no
# 4    173.0 ...    7.7   24    9200  3.2  yes  yes  yes  poor  yes  yes
# 5     95.0 ...    9.8   32    6900  3.4  yes   no   no  good   no  yes
# 6    264.0 ...   12.5   37    9600  4.1  yes  yes  yes  good  yes   no
# 7     70.0 ...   10.0   29   18900  3.5  yes  yes   no  good  yes   no
# 8    253.0 ...   10.5   33    7200  4.3  yes  yes  yes  good   no   no
# 9    163.0 ...    9.8   28   14600  3.2  yes  yes   no  good   no   no
# 10   129.0 ...    9.1   29    6400  3.4  yes   no   no  good   no   no
# 11   133.0 ...   10.3   36  \t6200    4   no  yes   no  good  yes   no
# 149   85.0 ...   15.6   44    5800  6.3   no   no   no  good   no   no
# 150  133.0 ...   14.8   46    6600  5.5   no   no   no  good   no   no
# 151  117.0 ...   13.0   54    7400  5.4   no   no   no  good   no   no
# 152  137.0 ...   14.1   45    9500  4.6   no   no   no  good   no   no
# 153  140.0 ...   15.7   47    6700  4.9   no   no   no  good   no   no
# 154   75.0 ...   16.5   54    7800  6.2   no   no   no  good   no   no
# 155  100.0 ...   15.8   49    6600  5.4   no   no   no  good   no   no
# 156  114.0 ...   14.2   51    7200  5.9   no   no   no  good   no   no
# 157  131.0 ...   15.8   53    6800  6.1   no   no   no  good   no   no
#
# [158 rows x 24 columns]

# %% [markdown]
# Let's build some color-coded labels; the actual label feature will be removed prior to executing PCA, since it's unsupervised. You're only labeling by color so you can see the effects of PCA:

# %%
labels = ['red' if i=='ckd' else 'green' for i in df.classification]

# %% [markdown]
# Use an indexer to select only the following columns: `['bgr','wc','rc']`

# %%
# .. your code here ..
df2.dtypes
# Out:
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# rbc       object
# pc        object
# pcc       object
# ba        object
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv       object
# wc        object
# rc        object
# htn       object
# dm        object
# cad       object
# appet     object
# pe        object
# ane       object
# dtype: object

# %% [markdown]
# Either take a look at the dataset's webpage in the attribute info section of UCI's [Chronic Kidney Disease]() page,: https://archive.ics.uci.edu/ml/datasets/Chronic_Kidney_Disease or alternatively, you can actually look at the first few rows of your dataframe using `.head()`. What kind of data type should these three columns be? Compare what you see with the results when you print out your dataframe's `dtypes`.
#
# If Pandas did not properly detect and convert your columns to the data types you expected, use an appropriate command to coerce these features to the right type.

# %%
# .. your code here ..
df2.bgr = pd.to_numeric(df2.bgr)
df2.wc = pd.to_numeric(df2.wc)
df2.rc = pd.to_numeric(df2.rc)
df2 = pd.get_dummies(df2,columns=['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'])

# %% [markdown]
# PCA Operates based on variance. The variable with the greatest variance will dominate. Examine your data using a command that will check the variance of every feature in your dataset, and then print out the results. Also print out the results of running `.describe` on your dataset.
#
# _Hint:_ If you do not see all three variables: `'bgr'`, `'wc'`, and `'rc'`, then it's likely you probably did not complete the previous step properly.

# %%
# .. your code here ..
df2.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000  158.000000
# mean    49.563291   74.050633    1.019873    0.797468    0.253165  131.341772
# std     15.512244   11.175381    0.005499    1.413130    0.813397   64.939832
# min      6.000000   50.000000    1.005000    0.000000    0.000000   70.000000
# 25%     39.250000   60.000000    1.020000    0.000000    0.000000   97.000000
# 50%     50.500000   80.000000    1.020000    0.000000    0.000000  115.500000
# 75%     60.000000   80.000000    1.025000    1.000000    0.000000  131.750000
# max     83.000000  110.000000    1.025000    4.000000    5.000000  490.000000
#
#                bu          sc         sod         pot     ...           dm_no  \
# count  158.000000  158.000000  158.000000  158.000000     ...      158.000000
# mean    52.575949    2.188608  138.848101    4.636709     ...        0.822785
# std     47.395382    3.077615    7.489421    3.476351     ...        0.383065
# min     10.000000    0.400000  111.000000    2.500000     ...        0.000000
# 25%     26.000000    0.700000  135.000000    3.700000     ...        1.000000
# 50%     39.500000    1.100000  139.000000    4.500000     ...        1.000000
# 75%     49.750000    1.600000  144.000000    4.900000     ...        1.000000
# max    309.000000   15.200000  150.000000   47.000000     ...        1.000000
#
#            dm_yes      cad_no     cad_yes  appet_good  appet_poor       pe_no  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000  158.000000
# m
.003180e+00  1.003180e+00  1.003180e+00  1.003180e+00
# min        ...      -2.154729e+00 -4.640955e-01 -3.655631e+00 -2.735506e-01
# 25%        ...       4.640955e-01 -4.640955e-01  2.735506e-01 -2.735506e-01
# 50%        ...       4.640955e-01 -4.640955e-01  2.735506e-01 -2.735506e-01
# 75%        ...       4.640955e-01 -4.640955e-01  2.735506e-01 -2.735506e-01
# max        ...       4.640955e-01  2.154729e+00  2.735506e-01  3.655631e+00
#
#          appet_good    appet_poor         pe_no        pe_yes        ane_no  \
# count  1.580000e+02  1.580000e+02  1.580000e+02  1.580000e+02  1.580000e+02
# mean   3.913887e-16 -3.927941e-16 -8.291539e-16  8.291539e-16 -1.686415e-16
# std    1.003180e+00  1.003180e+00  1.003180e+00  1.003180e+00  1.003180e+00
# min   -2.704772e+00 -3.697170e-01 -2.626785e+00 -3.806935e-01 -2.979094e+00
# 25%    3.697170e-01 -3.697170e-01  3.806935e-01 -3.806935e-01  3.356725e-01
# 50%    3.697170e-01 -3.697170e-01  3.806935e-01 -3.806935e-01  3.356725e-01
# 75%    3.697170e-01 -3.697170e-01  3.806935e-01 -3.806935e-01  3.356725e-01
# max    3.697170e-01  2.704772e+00  3.806935e-01  2.626785e+00  3.356725e-01
#
#             ane_yes
# count  1.580000e+02
# mean   7.869935e-17
# std    1.003180e+00
# min   -3.356725e-01
# 25%   -3.356725e-01
# 50%   -3.356725e-01
# 75%   -3.356725e-01
# max    2.979094e+00
#
# [8 rows x 34 columns]

# %% [markdown]
# Run PCA on your dataset, reducing it to 2 principal components. Make sure your PCA model is saved in a variable called `'pca'`, and that the results of your transformation are saved in another variable `'T'`:

# %%
# .. your code here ..
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(df)
T = pca.transform(df)

# %% [markdown]
# Now, plot the transformed data as a scatter plot. Recall that transforming the data will result in a NumPy NDArray. You can either use MatPlotLib to graph it directly, or you can convert it back to DataFrame and have Pandas do it for you.
#
# Since we've already demonstrated how to plot directly with MatPlotLib in `Module4/assignment1.ipynb`, this time we'll show you how to convert your transformed data back into to a Pandas Dataframe and have Pandas plot it from there.

# %%
# Since we transformed via PCA, we no longer have column names; but we know we
# are in `principal-component` space, so we'll just define the coordinates accordingly:
ax = drawVectors(T, pca.components_, df.columns.values, plt, scaleFeatures)
T  = pd.DataFrame(T)

T.columns = ['component1', 'component2']
T.plot.scatter(x='component1', y='component2', marker='o', c=labels, alpha=0.75, ax=ax)

plt.show()
# Out:
# Features by importance:
#  [(2.9696150394993324, 'ane_no'), (2.969615039499332, 'ane_yes'), (2.758875925894978, 'bgr'), (2.715504955394058, 'dm_yes'), (2.715504955394058, 'dm_no'), (2.658932094139237, 'pcv'), (2.6455721001098715, 'hemo'), (2.6021126628485067, 'al'), (2.5934172193046905, 'htn_no'), (2.5934172193046896, 'htn_yes'), (2.5767305659998625, 'su'), (2.4859440233443393, 'cad_no'), (2.4859440233443384, 'cad_yes'), (2.484132428132542, 'sc'), (2.479471113704938, 'pc_normal'), (2.4794711137049377, 'pc_abnormal'), (2.4651094161860527, 'appet_poor'), (2.4651094161860527, 'appet_good'), (2.4575665060850906, 'bu'), (2.393726969612572, 'sg'), (2.3881975796285317, 'rc'), (2.210578246131015, 'pe_yes'), (2.210578246131015, 'pe_no'), (2.1828180626076494, 'sod'), (2.0059261508175275, 'rbc_normal'), (2.0059261508175275, 'rbc_abnormal'), (1.9861731688066906, 'ba_present'), (1.9861731688066906, 'ba_notpresent'), (1.9842911319071963, 'pcc_present'), (1.9842911319071959, 'pcc_notpresent'), (1.2846796771566311, 'age'), (1.0541946042166224, 'bp'), (0.9193845987448063, 'wc'), (0.5640412875529994, 'pot')]
